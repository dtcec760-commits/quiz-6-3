# %% [markdown]
# <a href="https://colab.research.google.com/github/dtcec760-commits/quiz-6-3/blob/main/quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOG + CNN Object Classification (5 Classes)
# Runnable Google Colab Notebook

# %%
# !pip install torch torchvision scikit-image matplotlib

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import time

from skimage.feature import hog
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
IMG_SIZE = 128

def load_dataset(folder):

    data = []
    labels = []
    classes = os.listdir(folder)

    for label, class_name in enumerate(classes):

        path = os.path.join(folder, class_name)

        for img_name in os.listdir(path):

            img_path = os.path.join(path, img_name)

            img = cv2.imread(img_path)

            if img is None:
                continue

            img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
            img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

            data.append(img)
            labels.append(label)

    return np.array(data), np.array(labels), classes

# %% [markdown]
# # Problem 1

# %%
folder = "/content/drive/MyDrive/dataset/car_duck"

X,y,classes = load_dataset(folder)

print("Classes :",classes)
print("Total images :",len(X))
# Out:
# Classes : ['car', '.ipynb_checkpoints', 'duck']
# Total images : 144

# %%
print("============== WITHOUT HOG ==============")

X_flat = X.reshape(len(X),-1)

for ratio in [0.5,0.75]:

    X_train,X_test,y_train,y_test = train_test_split(
        X_flat,y,test_size=ratio,random_state=1)

    start = time.time()

    model = SVC()
    model.fit(X_train,y_train)

    pred = model.predict(X_test)

    end = time.time()

    acc = accuracy_score(y_test,pred)

    print("Test ratio :",ratio)
    print("Accuracy :",acc)
    print("Time :",end-start)
    print("-----------------------------")
def extract_hog(images):

    hog_features = []

    for img in images:

        features = hog(
            img,
            orientations=9,
            pixels_per_cell=(8,8),
            cells_per_block=(2,2)
        )

        hog_features.append(features)

    return np.array(hog_features)
print("============== WITH HOG ==============")

X_hog = extract_hog(X)

for ratio in [0.5,0.75]:

    X_train,X_test,y_train,y_test = train_test_split(
        X_hog,y,test_size=ratio,random_state=1)

    start = time.time()

    model = SVC()
    model.fit(X_train,y_train)

    pred = model.predict(X_test)

    end = time.time()

    acc = accuracy_score(y_test,pred)

    print("Test ratio :",ratio)
    print("Accuracy :",acc)
    print("Time :",end-start)
    print("-----------------------------")
# Out:
# ============== WITHOUT HOG ==============
# Test ratio : 0.5
# Accuracy : 0.9722222222222222
# Time : 0.12145519256591797
# -----------------------------
# Test ratio : 0.75
# Accuracy : 0.9722222222222222
# Time : 0.10532689094543457
# -----------------------------
# ============== WITH HOG ==============
# Test ratio : 0.5
# Accuracy : 0.9861111111111112
# Time : 0.034693241119384766
# -----------------------------
# Test ratio : 0.75
# Accuracy : 0.9814814814814815
# Time : 0.02127361297607422
# -----------------------------

# %% [markdown]
# # Problem 2

# %%
folder = "/content/drive/MyDrive/dataset/10_objects"

X,y,classes = load_dataset(folder)

print("Classes:",classes)
print("Total images:",len(X))
# Out:
# Classes: ['flower', '.ipynb_checkpoints', 'fruit', 'cat', 'dog', 'airplane', 'bike', 'apple', 'banana', 'duck']
# Total images: 9

# %%
def extract_hog(images):

    hog_features = []

    for img in images:

        features = hog(
            img,
            orientations=9,
            pixels_per_cell=(8,8),
            cells_per_block=(2,2)
        )

        hog_features.append(features)

    return np.array(hog_features)

X_hog = extract_hog(X)

print("HOG Feature shape:",X_hog.shape)
# Out:
# HOG Feature shape: (9, 8100)

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X_hog,
    y,
    test_size=0.3,
    random_state=1
)
model = MLPClassifier(
    hidden_layer_sizes=(128,64),
    max_iter=500
)

model.fit(X_train,y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=500)

# %%
pred = model.predict(X_test)

accuracy = accuracy_score(y_test,pred)

print("Neural Network Accuracy =",accuracy)
# Out:
# Neural Network Accuracy = 0.0
